# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from handle_dataset.transform import create_df_with_datetimes

# %%
data_df = pd.read_csv('Dataset/Yearly-train.csv')
info_df = pd.read_csv('Dataset/M4-info.csv')

# %%
first_timeseries = create_df_with_datetimes(data_df, 0)
first_timeseries['timestamp'] = pd.to_datetime(first_timeseries['timestamp'])
first_timeseries['year'] = first_timeseries['timestamp'].dt.year
plt.figure(figsize=(15,6))
plt.plot(first_timeseries['year'].tolist(), first_timeseries['target'].tolist())
plt.xticks(first_timeseries['year'].values.astype(int))
plt.title('Macro - 0')
plt.xlabel('Timestamp')
plt.ylabel('Target')
# Out:
# /tmp/ipykernel_114780/2968560060.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   first_timeseries['timestamp'] = pd.to_datetime(first_timeseries['timestamp'])
# Text(0, 0.5, 'Target')

# %%
random_timeseries = create_df_with_datetimes(data_df, 9827)
random_timeseries['timestamp'] = pd.to_datetime(random_timeseries['timestamp'])
random_timeseries['year'] = random_timeseries['timestamp'].dt.year
plt.figure(figsize=(15,6))
plt.plot(random_timeseries['year'].tolist(), random_timeseries['target'].tolist())
plt.xticks(random_timeseries['year'].values.astype(int))
plt.title('Micro - 9827')
plt.xlabel('Timestamp')
plt.ylabel('Target')
# Out:
# /tmp/ipykernel_114780/3751675643.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   random_timeseries['timestamp'] = pd.to_datetime(random_timeseries['timestamp'])
# Text(0, 0.5, 'Target')

# %%
random_timeseries = create_df_with_datetimes(data_df, 11770)
random_timeseries['timestamp'] = pd.to_datetime(random_timeseries['timestamp'])
random_timeseries['year'] = random_timeseries['timestamp'].dt.year
plt.figure(figsize=(15,6))
plt.plot(random_timeseries['year'].tolist(), random_timeseries['target'].tolist())
plt.xticks(random_timeseries['year'].values.astype(int))
plt.title('Industry - 11770')
plt.xlabel('Timestamp')
plt.ylabel('Target')
# Out:
# /tmp/ipykernel_114780/2109266567.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   random_timeseries['timestamp'] = pd.to_datetime(random_timeseries['timestamp'])
# Text(0, 0.5, 'Target')

# %%
random_timeseries = create_df_with_datetimes(data_df, 16399)
random_timeseries['timestamp'] = pd.to_datetime(random_timeseries['timestamp'], format="%d-%m-%y %H:%M")
random_timeseries['year'] = random_timeseries['timestamp'].dt.to_period('Y').astype(str).astype(int)
# random_timeseries['year'] = random_timeseries['timestamp'].dt.floor('Y').year
plt.figure(figsize=(15,6))
plt.plot(random_timeseries['year'].values.astype(int), random_timeseries['target'].tolist())
plt.xticks(random_timeseries['year'].values.astype(int))
plt.title('Finance - 16399')
plt.xlabel('Timestamp')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %%
random_timeseries = create_df_with_datetimes(data_df, 10590)
random_timeseries['timestamp'] = pd.to_datetime(random_timeseries['timestamp'])
random_timeseries['year'] = random_timeseries['timestamp'].dt.year
plt.figure(figsize=(15,6))
plt.plot(random_timeseries['year'].tolist(), random_timeseries['target'].tolist())
plt.xticks(random_timeseries['year'].values.astype(int))
plt.title('Demographic - 10590')
plt.xlabel('Timestamp')
plt.ylabel('Target')
# Out:
# /tmp/ipykernel_114780/3424302227.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   random_timeseries['timestamp'] = pd.to_datetime(random_timeseries['timestamp'])
# Text(0, 0.5, 'Target')

# %%
random_timeseries = create_df_with_datetimes(data_df, 22200)
random_timeseries['timestamp'] = pd.to_datetime(random_timeseries['timestamp'])
random_timeseries['year'] = random_timeseries['timestamp'].dt.year
plt.figure(figsize=(15,6))
plt.plot(random_timeseries['year'].tolist(), random_timeseries['target'].tolist())
plt.xticks(random_timeseries['year'].values.astype(int))
plt.title('Other - 22200')
plt.xlabel('Timestamp')
plt.ylabel('Target')
# Out:
# /tmp/ipykernel_114780/812766696.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   random_timeseries['timestamp'] = pd.to_datetime(random_timeseries['timestamp'])
# Text(0, 0.5, 'Target')
